# %%
#import statements
import csv, random

# %%
#termination criteria is when fitness < 0.01

def randomOp():
        options = ['+', '-', '*', '/', 'x', '-2', '-1', '1', '2']
        length = len(options)
        #generate random operation
        value = random.randint(0,length-1)
        return options[value]

class Tree:
    #initialize
    print("initialize tree")
    # make sure tree class is immutable
    def __init__(self):
        '''
        if copy is None:
            self.root = randomTree()
        else:
            #not sure we need tuples ?
            if type(order) != type(()):
                raise ValueError('order must be specified using a tuple')
            self.root = copy.root
        '''
        #initial tree -> call random tree generator
        #mutated tree -> call clone; makes copy of tree with changes
        # Node root
        self.root = Node()
        self.root.value = randomOp()
        
        self._initialTree(self.root)
        

    def evaluate(x):
        #evaluates fitness of a tree
        #needs to be very efficient

        #scan/traverse tree for operators and look at left and right (its children)
        #incorporate order of operations
        #use if statements to determine next actions
        #recursive function to solve subtrees
        #ex: if + then add recursice simplification of one subtree to the simplification of other subtree
        
        #returns float or int
        val = 0
        return val

    def firstVal(self):
        start = Node()
        #set root of tree to first val
        self.root = start

        #generate random operation
        val = randomOp()
        #set node value
        start.value = val
        print(start.value)
        return start

    def _initialTree(self, node):
        
        operators = ['+', '-', '*', '/']
        operands = ['x', '-2', '-1', '1', '2']
        
        if (node.value in operators):
            #print("enter operator = ", node.value)
            
            leftNode = Node()
            leftNode.value = randomOp()
            node.left = leftNode
            
            rightNode = Node()
            rightNode.value = randomOp()
            node.right = rightNode
            
            self._initialTree(leftNode)
            self._initialTree(rightNode)
            
        elif (node.value in operands):
            #print("enter operand = ", node.value)

        #base case?
        #while(node.value in operators):
        #check if value is operand and right -> break
        # if operator or left-> continue

    def initialPop(self):
        #calls initial tree to create initial population
        forrest = []
        for i in range(10):
            newTree = Tree()
            forrest.append(newTree)
        print(forrest[0].root)

class Node:
    #initialize
    print("initialize node")
    def __init__(self):
        # Node parent, left, right
        self.parent = ''
        self.left = ''
        self.right = ''
        # Value: contents of the node (type: str)
        self.value = ''

# IN ORDER TREE TRAVERSAL
# looks at node the second time you hit it
# build string as you traverse; when you hit leaf node, add to string
# when you hit parent for second time, add to string
# Out:
#   Input In [92]
#     def initialPop(self):
#     ^
# IndentationError: expected an indented block

# %%
def main():
    with open('dataset1.csv', newline='') as csvfile:
        data = list(csv.reader(csvfile))
    data = data[1:]
    train = data[0:20000]
    test = data[20000:]
    #print(data[0:10])
    tree = Tree()
    tree.initialPop()

if __name__ == "__main__":
    main()
# Out:
# enter operator =  *
# enter operator =  +
# enter operator =  +
# enter operand =  1
# enter operator =  +
# enter operator =  /
# enter operand =  x
# enter operator =  -
# enter operand =  x
# enter operand =  -1
# enter operator =  +
# enter operand =  1
# enter operand =  x
# enter operator =  *
# enter operand =  -2
# enter operator =  *
# enter operator =  *
# enter operator =  /
# enter operator =  *
# enter operator =  +
# enter operand =  -1
# enter operator =  *
# enter operand =  -2
# enter operator =  +
# enter operand =  x
# enter operand =  2
# enter operand =  2
# enter operator =  +
# enter operand =  2
# enter operator =  *
# enter operand =  2
# enter operator =  -
# enter operand =  -1
# enter operand =  -1
# enter operand =  -2
# enter operator =  +
# enter operator =  -
# enter operand =  x
# enter operand =  2
# enter operand =  -2
# enter operand =  1
# enter operator =  -
# enter operand =  -1
# enter operand =  2
# enter operator =  /
# enter operand =  1
# enter operand =  -2
# enter operator =  /
# enter operator =  *
# enter operator =  *
# enter operand =  -2
# enter operator =  -
# enter operator =  /
# enter operator =  +
# enter operator =  *
# enter operator =  -
# enter operator =  /
# enter operand =  1
# enter operator =  -
# enter operand =  -2
# enter operand =  x
# enter operator =  +
# enter operator =  *
# enter operator =  -
# enter operand =  -2
# enter operand =  2
# enter operand =  1
# enter operator =  +
# enter operator =  +
# enter operand =  x
# enter operand =  x
# enter operator =  /
# enter operand =  -1
# enter operator =  -
# enter operand =  1
# enter operand =  2
# enter operator =  /
# enter operand =  -1
# enter operand =  x
# enter operator =  /
# enter operand =  -1
# enter operator =  -
# enter operand =  -2
# enter operand =  x
# enter operand =  2
# enter operand =  1
# enter operand =  1
# enter operator =  /
# enter operator =  +
# enter operand =  -2
# enter operand =  -1
# enter operand =  1
# enter operand =  1
# enter operator =  /
# enter operand =  x
# enter operand =  -1
# enter operand =  2
# enter operator =  *
# enter operator =  *
# enter operand =  -2
# enter operand =  x
# enter operand =  1
# enter operand =  1
# enter operand =  1
# enter operand =  1
# [<__main__.Tree object at 0x149a4a893df0>, <__main__.Tree object at 0x149a4a006be0>, <__main__.Tree object at 0x149a4a006490>, <__main__.Tree object at 0x149a4aaf7550>, <__main__.Tree object at 0x149a4a037d90>, <__main__.Tree object at 0x149a4ac453d0>, <__main__.Tree object at 0x149a4ac45ca0>, <__main__.Tree object at 0x149a4ac45a90>, <__main__.Tree object at 0x149a4ac45700>, <__main__.Tree object at 0x149a4ac45f10>]
